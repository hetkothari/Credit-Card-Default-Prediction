# %% [markdown]
# <a href="https://colab.research.google.com/github/hetkothari/Credit-Card-Default-Prediction/blob/main/Credit_Card_Default_Personal_Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Problem Description
# This project is aimed at predicting the case of customers default payments in Taiwan. From the perspective of risk management, the result of predictive accuracy of the estimated probability of default will be more valuable than the binary result of classification - credible or not credible clients.

# %% [markdown]
# ##Import libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ##Load Dataset

# %%
data= pd.read_excel("/content/drive/MyDrive/Credit Card Default Prediction - Het Kothari/dataset.xlsx")
data
# Out:
#           ID  LIMIT_BAL  SEX  ...  PAY_AMT5  PAY_AMT6  default payment next month
# 0          1      20000    2  ...         0         0                           1
# 1          2     120000    2  ...         0      2000                           1
# 2          3      90000    2  ...      1000      5000                           0
# 3          4      50000    2  ...      1069      1000                           0
# 4          5      50000    1  ...       689       679                           0
# ...      ...        ...  ...  ...       ...       ...                         ...
# 29995  29996     220000    1  ...      5000      1000                           0
# 29996  29997     150000    1  ...         0         0                           0
# 29997  29998      30000    1  ...      2000      3100                           1
# 29998  29999      80000    1  ...     52964      1804                           1
# 29999  30000      50000    1  ...      1000      1000                           1
#
# [30000 rows x 25 columns]

# %%
data.describe()
# Out:
#                  ID       LIMIT_BAL  ...       PAY_AMT6  default payment next month
# count  30000.000000    30000.000000  ...   30000.000000                30000.000000
# mean   15000.500000   167484.322667  ...    5215.502567                    0.221200
# std     8660.398374   129747.661567  ...   17777.465775                    0.415062
# min        1.000000    10000.000000  ...       0.000000                    0.000000
# 25%     7500.750000    50000.000000  ...     117.750000                    0.000000
# 50%    15000.500000   140000.000000  ...    1500.000000                    0.000000
# 75%    22500.250000   240000.000000  ...    4000.000000                    0.000000
# max    30000.000000  1000000.000000  ...  528666.000000                    1.000000
#
# [8 rows x 25 columns]

# %%
data.shape
# Out:
# (30000, 25)

# %%
data.isnull().sum()
# Out:
# ID                            0
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_0                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default payment next month    0
# dtype: int64

# %%
data.columns
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month'],
#       dtype='object')

# %% [markdown]
# ##Rename Columns

# %%
data = data.rename(columns={'default payment next month': 'def_pay', 'PAY_0': 'PAY_1'})
data.rename(columns={'PAY_1':'PAY_SEPT','PAY_2':'PAY_AUG','PAY_3':'PAY_JUL','PAY_4':'PAY_JUN','PAY_5':'PAY_MAY','PAY_6':'PAY_APR'},inplace=True)
data.rename(columns={'BILL_AMT1':'BILL_AMT_SEPT','BILL_AMT2':'BILL_AMT_AUG','BILL_AMT3':'BILL_AMT_JUL','BILL_AMT4':'BILL_AMT_JUN','BILL_AMT5':'BILL_AMT_MAY','BILL_AMT6':'BILL_AMT_APR'}, inplace = True)
data.rename(columns={'PAY_AMT6':'PAY_AMT_MAR','PAY_AMT1':'PAY_AMT_AUG','PAY_AMT2':'PAY_AMT_JUL','PAY_AMT3':'PAY_AMT_JUN','PAY_AMT4':'PAY_AMT_MAY','PAY_AMT5':'PAY_AMT_APR'},inplace=True)

# %%
data.columns
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_SEPT',
#        'PAY_AUG', 'PAY_JUL', 'PAY_JUN', 'PAY_MAY', 'PAY_APR', 'BILL_AMT_SEPT',
#        'BILL_AMT_AUG', 'BILL_AMT_JUL', 'BILL_AMT_JUN', 'BILL_AMT_MAY',
#        'BILL_AMT_APR', 'PAY_AMT_AUG', 'PAY_AMT_JUL', 'PAY_AMT_JUN',
#        'PAY_AMT_MAY', 'PAY_AMT_APR', 'PAY_AMT_MAR', 'def_pay'],
#       dtype='object')

# %%
len(data[data.duplicated()])
# Out:
# 0

# %% [markdown]
# ##Create Features

# %%
data = data.replace([-2],0)
data.head()
# Out:
#    ID  LIMIT_BAL  SEX  ...  PAY_AMT_APR  PAY_AMT_MAR  def_pay
# 0   1      20000    2  ...            0            0        1
# 1   2     120000    2  ...            0         2000        1
# 2   3      90000    2  ...         1000         5000        0
# 3   4      50000    2  ...         1069         1000        0
# 4   5      50000    1  ...          689          679        0
#
# [5 rows x 25 columns]

# %%
data["pay"]=data["PAY_SEPT"]+data["PAY_AUG"]+data["PAY_JUL"]+data["PAY_JUN"]+data["PAY_MAY"]+data["PAY_APR"]
data["pay"].describe()
# Out:
# count    30000.000000
# mean         0.533033
# std          4.408759
# min         -6.000000
# 25%         -1.000000
# 50%          0.000000
# 75%          1.000000
# max         36.000000
# Name: pay, dtype: float64

# %% [markdown]
# ##Univriate Analysis

# %%
list1 = ["BILL_AMT_SEPT",	"BILL_AMT_AUG"	,"BILL_AMT_JUL"	,"BILL_AMT_JUN"	,"BILL_AMT_MAY"	,"BILL_AMT_APR","PAY_AMT_AUG",'PAY_AMT_JUL',	'PAY_AMT_JUN'	,'PAY_AMT_MAY'	,'PAY_AMT_APR'	,'PAY_AMT_MAR']

# %%
for column in list1[:]:
  fig= plt.figure(figsize=(12,6))
  ax= fig.gca()
  sns.histplot(data=data, x= column, ax= ax)
plt.show()

# %%
data["MARRIAGE"].value_counts(normalize= True)
# Out:
# 2    0.532133
# 1    0.455300
# 3    0.010767
# 0    0.001800
# Name: MARRIAGE, dtype: float64

# %%
data["EDUCATION"].value_counts(normalize= True)
# Out:
# 2    0.467667
# 1    0.352833
# 3    0.163900
# 5    0.009333
# 4    0.004100
# 6    0.001700
# 0    0.000467
# Name: EDUCATION, dtype: float64

# %%
data["def_pay"].value_counts(normalize= True)
# Out:
# 0    0.7788
# 1    0.2212
# Name: def_pay, dtype: float64

# %% [markdown]
# Only 22% defaulters in our data set.

# %%
data["SEX"].value_counts(normalize= True)
# Out:
# 2    0.603733
# 1    0.396267
# Name: SEX, dtype: float64

# %% [markdown]
# Higher female credit card users.

# %%
plt.figure(figsize=(15,7))
sns.countplot(x = 'AGE', data = data)
plt.show()

# %% [markdown]
# 23-39 is the Age with high credit card users.

# %%
data['LIMIT_BAL'].value_counts()
# Out:
# 50000      3365
# 20000      1976
# 30000      1610
# 80000      1567
# 200000     1528
#            ...
# 800000        2
# 760000        1
# 690000        1
# 1000000       1
# 327680        1
# Name: LIMIT_BAL, Length: 81, dtype: int64

# %% [markdown]
# ##Bivariate Analysis

# %%
x,y = 'EDUCATION', 'def_pay'

(data
.groupby(x)[y]
.value_counts(normalize=True)
.mul(100)
.rename('percent')
.reset_index()
.pipe((sns.catplot,'data'), x=x,y='percent',hue=y,kind='bar'))

# %% [markdown]
# Higher schoolers have higher slightly higheer defaulter rate.

# %%
x,y = 'MARRIAGE', 'def_pay'

(data
.groupby(x)[y]
.value_counts(normalize=True)
.mul(100)
.rename('percent')
.reset_index()
.pipe((sns.catplot,'data'), x=x,y='percent',hue=y,kind='bar'))

# %% [markdown]
# Slightly higher default rate in others category.

# %%
x,y = 'SEX', 'def_pay'

(data
.groupby(x)[y]
.value_counts(normalize=True)
.mul(100)
.rename('percent')
.reset_index()
.pipe((sns.catplot,'data'), x=x,y='percent',hue=y,kind='bar'))

# %% [markdown]
# Males are slightly higher defaulters compared to females.

# %%
plt.figure(figsize=(19,7))
sns.barplot(x = 'AGE', y = 'def_pay', data = data)

plt.show()

# %%
plt.figure(figsize=(10,5))
sns.boxplot(x='def_pay',y='AGE',data=data)
plt.xlabel("0=Non defaulter, 1= Defaulter")
plt.show()

# %% [markdown]
# Age is not affecting much.

# %%
sns.boxplot(data=data, y="pay",x="def_pay")
plt.xlabel("0=Non defaulter, 1= Defaulter")
plt.show()

# %% [markdown]
# Higher default history will result higher future deafulter.

# %% [markdown]
# ##Outlier Removal

# %% [markdown]
# Customer who have a great history but default for next month will affect our model therefore we will remove them.

# %%
print (data["def_pay"].value_counts())
data = data.drop(data[(data.def_pay == 1) & (data.PAY_SEPT < 1) & (data.PAY_AUG < 1) & (data.PAY_JUL < 1) & (data.PAY_JUN < 1) & (data.PAY_MAY < 1)].index)
data["def_pay"].value_counts()
# Out:
# 0    23364
# 1     6636
# Name: def_pay, dtype: int64
# 0    23364
# 1     4206
# Name: def_pay, dtype: int64

# %% [markdown]
# ##Correlation Graph

# %%
plt.figure (figsize= (20,10))
corelation= data.corr()
sns.heatmap(corelation, annot=True)

# %% [markdown]
# A lot of historical data has almost no correlation with target variable so we will drop thoe columns

# %%
data.drop(['ID'], axis=1, inplace=True)
data.drop(['AGE',"MARRIAGE"], axis=1, inplace=True)
data.drop(["BILL_AMT_MAY","BILL_AMT_APR","BILL_AMT_JUN","PAY_AMT_MAY","PAY_AMT_APR","PAY_AMT_MAR"], axis=1, inplace=True)

# %%
data = pd.get_dummies(data,columns=['EDUCATION','SEX'])

# %% [markdown]
# ##Preparing Dataset for Training

# %%
X= data.drop(['def_pay'], axis = 1)
y= data.def_pay

X = X.apply(lambda x : (x-np.mean(x))/np.std(x))

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X, y, test_size = 0.5, random_state = 1)

# %% [markdown]
# We will over sample based on target variable

# %%
from collections import Counter
from imblearn.over_sampling import RandomOverSampler

os = RandomOverSampler()

# fit predictor and target variable
X_train_os, y_train_os = os.fit_sample(X_train, y_train)

print('Original dataset shape', Counter(y_train))
print('Resample dataset shape', Counter(y_train_os))
# Out:
# Original dataset shape Counter({0: 11647, 1: 2138})
# Resample dataset shape Counter({0: 11647, 1: 11647})

# %% [markdown]
# ##Logistic Model

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV

param_grid = {'penalty':['l1','l2'], 'C' : [0.0001,0.001, 0.01, 0.1,  0.3, 0.5, 0.6, 0.7, 0.8, 0.9, 1] }

logistic_model= GridSearchCV(LogisticRegression(), param_grid, scoring = 'recall', n_jobs = -1, verbose = 3, cv = 3)
logistic_model.fit(X_train_os, y_train_os)
# Out:
# Fitting 3 folds for each of 22 candidates, totalling 66 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  56 tasks      | elapsed:    3.3s
# [Parallel(n_jobs=-1)]: Done  66 out of  66 | elapsed:    3.7s finished
# GridSearchCV(cv=3, error_score=nan,
#              estimator=LogisticRegression(C=1.0, class_weight=None, dual=False,
#                                           fit_intercept=True,
#                                           intercept_scaling=1, l1_ratio=None,
#                                           max_iter=100, multi_class='auto',
#                                           n_jobs=None, penalty='l2',
#                                           random_state=None, solver='lbfgs',
#                                           tol=0.0001, verbose=0,
#                                           warm_start=False),
#              iid='deprecated', n_jobs=-1,
#              param_grid={'C': [0.0001, 0.001, 0.01, 0.1, 0.3, 0.5, 0.6, 0.7,
#                                0.8, 0.9, 1],
#                          'penalty': ['l1', 'l2']},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring='recall', verbose=3)

# %%
y_pred_logistic_test = logistic_model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix

# %%
logistic_test_confusion_matrix= confusion_matrix(y_test, y_pred_logistic_test)
print(logistic_test_confusion_matrix)
# Out:
# [[10266  1451]
#  [  385  1683]]

# %%
logistic_test_accuracy= accuracy_score(y_test, y_pred_logistic_test)
logistic_test_accuracy
# Out:
# 0.8668117519042438

# %% [markdown]
# ##Support Vector Machine

# %%
from sklearn import svm
 
#Create a svm Classifier
svm_model = svm.SVC(kernel='rbf',gamma='scale') 
 
#Train the model using the training sets
svm_model.fit(X_train_os, y_train_os)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
y_pred_svm_test = svm_model.predict(X_test)

# %%
svm_test_confusion_matrix= confusion_matrix(y_test, y_pred_svm_test)
print(svm_test_confusion_matrix)
# Out:
# [[9360 2357]
#  [  80 1988]]

# %%
svm_test_accuracy= accuracy_score(y_test, y_pred_svm_test)
svm_test_accuracy
# Out:
# 0.8232136380123323

# %% [markdown]
# #Conclusion

# %% [markdown]
# So we can conclude after implementing two models
#
#
# 1.   Logistic model has higher accuracy
# 2.   SVM model has higher recall
